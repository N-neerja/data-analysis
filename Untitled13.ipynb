# %%
# importing the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#!pip lnstall seaborn --upgrade
sns.get_dataset_names()
df= sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
df.describe(include='float')
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df.describe(include='int64')
# Out:
#              size
# count  244.000000
# mean     2.569672
# std      0.951100
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      6.000000

# %%
# INSIGHTS FROM THE TIPS DATASET

# 1. Weekend dinners generate the highest average total bills and tips.
# 2. Saturday dinner is the most profitable time period.
# 3. Dinner sessions outperform lunch in average spending and tipping.
# 4. Most dining tables consist of 2 to 3 people.
# 5. Larger groups pay higher total bills but tip less per person.
# 6. Non-smokers tip slightly more on average than smokers.

# %%
# Null value treatment and imputations
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#!pip lnstall seaborn --upgrade
sns.get_dataset_names()
df= sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

print(missing_percentage)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
# Out:
# 79.57351290684625

# %%
((df.isna().sum())/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['embarked'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['class'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['adult_male'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['deck'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['embark_town'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alone'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alive'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alone'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['fare'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alone'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'],hue=df['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alone'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['who'],hue=df['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['fare'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['pclass'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['who'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['age'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'],hue=df['alone'])
plt.show()
